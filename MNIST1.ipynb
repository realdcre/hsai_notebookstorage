# %%
import tensorflow as tf #import tensorflow library
from tensorflow import keras
import matplotlib.pyplot as plt #import matplotlib library
import scipy.special #import scipy for sigmoid function
print(tf.__version__)
# Out:
# 2.7.0

# %%
 #Importiere MNIST-Daten per Tensorflow/Keras 
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data(path="mnist.npz")
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
plt.imshow(test_images[9999], cmap='Greys')
test_labels[9999]
# Out:
# 6

# %%
erstesBild = 0 # erhöhen, um andere Daten zu sehen 
plt.figure(figsize=(10,10)) 
for i in range(0,25): 
 plt.subplot(5,5,i+1) 
 plt.xticks([]) 
 plt.yticks([]) 
 plt.grid(False) 
 plt.imshow(test_images[i+erstesBild], cmap='Greys') 
 plt.xlabel('#'+str(i+erstesBild)+' Label: '+str(test_labels[i+erstesBild])) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\HECTOR~1\AppData\Local\Temp/ipykernel_10944/832288195.py in <module>
#       2 plt.figure(figsize=(10,10))
#       3 for i in range(0,100):
# ----> 4  plt.subplot(5,5,i+1)
#       5  plt.xticks([])
#       6  plt.yticks([])
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1270
#    1271     # First, search for an existing subplot with a matching spec.
# -> 1272     key = SubplotSpec._from_subplot_args(fig, args)
#    1273
#    1274     for ax in fig.axes:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     651                     num = int(num)
#     652                 if num < 1 or num > rows*cols:
# --> 653                     raise ValueError(
# ...
